# %% [markdown]
# # Imports

# %%
import os
import sys
import pandas as pd


from dotenv import load_dotenv
import requests
from sqlalchemy import create_engine


current_dir = os.path.dirname(os.path.abspath('/Users/maukanmir/Documents/Machine-Learning/Web-Scraping-Code/Player-Salaries/scraping/height_weight.ipynb'))
project_root = os.path.join(current_dir, '..')
sys.path.insert(0, project_root)

from packages.utils import grab_heights_weights

# %% [markdown]
# # Constants

# %%
dotenv_path = ("/Users/maukanmir/Documents/Machine-Learning/Web-Scraping-Code/Player-Salaries/dot.env")
load_dotenv(dotenv_path)

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")
TABLE_NAME_PlAYER_BIOMETRIC= "player_biometric_data"

engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}')

# %%
years = [str(year) for year in range(1970, 2025)]

# %%
all_data = pd.DataFrame()
for year in years:
  
  base_url = f"https://basketball.realgm.com/nba/players/{year}"
  response = requests.get(base_url)
  df = grab_heights_weights(response.text, year)
  all_data = pd.concat([all_data, df])

# %%
all_data
# Out:
#                     name pos height  weight  age  team  gp  yos  \
# 0        Zaid Abdul-Aziz  FC    6-9     235   23   MIL  80    1
# 1    Kareem Abdul-Jabbar   C    7-2     225   22   MIL  82    0
# 2     Mahdi Abdul-Rahman   G    6-2     185   27   ATL  82    5
# 3           Rick Adelman  PG    6-1     175   23   SDR  35    1
# 4           Lucius Allen  PG    6-2     175   22   SEA  80    0
# ..                   ...  ..    ...     ...  ...   ...  ..  ...
# 567       Thaddeus Young   F    6-8     225   35   TOR  33   16
# 568           Trae Young  PG    6-1     164   25   ATL  54    5
# 569       Omer Yurtseven   C   6-11     275   25   UTA  48    3
# 570          Cody Zeller   F   6-11     240   31   NOP  43   10
# 571          Ivica Zubac   C    7-0     240   26   LAC  68    7
#
#                college-team               draft-status  \
# 0                Iowa State          1968 Rnd 1 Pick 5
# 1                      UCLA          1969 Rnd 1 Pick 1
# 2                      UCLA  1964 NBA Draft, Undrafted
# 3          Loyola Marymount          1968 Rnd 7 Pick 1
# 4                      UCLA          1969 Rnd 1 Pick 3
# ..                      ...                        ...
# 567            Georgia Tech         2007 Rnd 1 Pick 12
# 568                Oklahoma          2018 Rnd 1 Pick 5
# 569              Georgetown  2020 NBA Draft, Undrafted
# 570                 Indiana          2013 Rnd 1 Pick 4
# 571  KK Mega Bemax (Serbia)          2016 Rnd 2 Pick 2
#
#                        nationality     season
# 0                    United States  1970-1971
# 1                    United States  1970-1971
# 2                    United States  1970-1971
# 3                    United States  1970-1971
# 4                    United States  1970-1971
# ..                             ...        ...
# 567                  United States  2024-2025
# 568                  United States  2024-2025
# 569               UzbekistanTurkey  2024-2025
# 570                  United States  2024-2025
# 571  Bosnia and HerzegovinaCroatia  2024-2025
#
# [21773 rows x 12 columns]

# %%
try:
    all_data.to_sql(TABLE_NAME_PlAYER_BIOMETRIC, engine, if_exists='replace', index=False)
    print("Data successfully written to the database.")
except Exception as e:
    print(f"Database operation failed. Error: {e}")
# Out:
# Data successfully written to the database.
