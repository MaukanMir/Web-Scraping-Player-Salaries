# %% [markdown]
# # Imports

# %%
import os
import pandas as pd


from dotenv import load_dotenv
import requests
from sqlalchemy import create_engine

# %% [markdown]
# # Constants

# %%
dotenv_path = ("/Users/maukanmir/Documents/Machine-Learning/Web-Scraping-Code/Scraping-Files/Player-Salaries/dot.env")
load_dotenv(dotenv_path)

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")
TABLE_NAME_PlAYER_BIOMETRIC= "player_biometric_data"

engine = create_engine(f'postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}')

# %%
from bs4 import BeautifulSoup

url ="https://basketball.realgm.com/nba/players/2024"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")
tds = [td.text for td in soup.find_all("td", class_="nowrap")]
columns = ["name", "pos","height", "weight", "age", "yos", "draft-status", "nationality"]

df = []
players = {}
count = 0
for value in tds:
  if count <8:
    players[columns[count]] = value
    count +=1
    
    if count == 7:
      count =0
      df.append(players)
      players={}

df = pd.DataFrame(df)
df
# Out:
#                    name                        pos              height  \
# 0      Precious Achiuwa                         SF                 6-8
# 1               Nigeria                Bam Adebayo                   C
# 2    2017 Rnd 1 Pick 14              United States        Ochai Agbaji
# 3                     1         2022 Rnd 1 Pick 14       United States
# 4                    23                          2  2021 Rnd 1 Pick 30
# ..                  ...                        ...                 ...
# 648      Thaddeus Young                          F                 6-8
# 649       United States                 Trae Young                  PG
# 650   2018 Rnd 1 Pick 5              United States      Omer Yurtseven
# 651                   3  2020 NBA Draft, Undrafted    UzbekistanTurkey
# 652                  31                         10   2013 Rnd 1 Pick 4
#
#             weight                       age   yos        draft-status
# 0              243                        24     3  2020 Rnd 1 Pick 20
# 1              6-9                       255    26                   6
# 2               SF                       6-5   215                  23
# 3     Santi Aldama                         C   7-0                 215
# 4            Spain  Nickeil Alexander-Walker    SG                 6-5
# ..             ...                       ...   ...                 ...
# 648            225                        35    16  2007 Rnd 1 Pick 12
# 649            6-1                       164    25                   5
# 650              C                      6-11   275                  25
# 651    Cody Zeller                         F  6-11                 240
# 652  United States               Ivica Zubac     C                 7-0
#
# [653 rows x 7 columns]
